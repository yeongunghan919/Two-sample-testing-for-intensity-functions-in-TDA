# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../../source"))
from TDA_Testing import *
import pickle
def savepkl(obj, path):
    with open(path, 'wb') as f:
        pickle.dump(obj, f)

def loadpkl(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

# %%
N=60
flute = [pd.read_csv(f"../../data/flute_diagrams/flute_onedim_{i}.csv").to_numpy() for i in range(1, N+1)]
clarinet = [pd.read_csv(f"../../data/clarinet_diagrams/clarinet_onedim_{i}.csv").to_numpy() for i in range(1, N+1)]

# %%
flute_gr1 = flute[:20]
flute_gr2 = flute[21:40]
flute_gr3 = flute[41:60]
clarinet_gr1 = clarinet[:20]
clarinet_gr2 = clarinet[21:40]
clarinet_gr3 = clarinet[41:60]

# %%
func_weight = function_weight("constant")
flute_flute=Aggtest(flute_gr1,flute_gr2,optimal_bandwidths=True,weight_function=func_weight,Rff_approx=True,return_dictionary=True)
flute_clarinet=Aggtest(flute_gr3,clarinet_gr3,optimal_bandwidths=True,weight_function=func_weight,Rff_approx=True,return_dictionary=True)
clarinet_clarinet=Aggtest(clarinet_gr1,clarinet_gr2,optimal_bandwidths=True,weight_function=func_weight,Rff_approx=True,return_dictionary=True)

# %%
pval=[]
for result in [clarinet_clarinet,flute_flute,flute_clarinet]:
   pval.append(result[1]['p-value'])
pval
# Out:
# [0.8601398601398601, 0.4935064935064935, 0.000999000999000999]
